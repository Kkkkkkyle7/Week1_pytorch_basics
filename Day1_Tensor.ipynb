# %% [markdown]
# # Day1（2.9）：张量操作「手感训练」
# ## 1. 张量创建

# %%
import torch
x = torch.tensor([[1,2],[3,4]])   # 从列表创建
y = torch.rand(3,2)               # 随机张量
z = torch.zeros(2,3).cuda()       # GPU零张量
                                  # 或.to('cuda')

# %% [markdown]
# ## 2. 核心操作
# 1. 创建形状$(4,5)$的全1张量 $\to$ 转float32
# 2. 用`view()`将$(2,3,4)$张量展平为$(24,)$
# 3. 用广播计算：`a=torch.tensor([1,2]); b=torch.tensor([[1],[2]]); a+b`
# 4. 将CPU张量`x`迁移到GPU（若可用）

# %%
# 全1张量
all_one = torch.ones(4,5)
all_one_float = all_one.float()

# %%
tensor = torch.tensor(2,3,4)
reshaped_tensor = tensor.view(24,)
